# %% [markdown]
# # Touchsada Jan On - Assignment 4: Tortoise v. Hare, OOP edition
# # CS120 Dean Zeller
# ### Submission Date: Friday, November 22th, 2019
# ### Description: The following program will implement Tortoise v. Hare methods within object oriented program. Each one will be descripted below.
# ### Copyright: This program is © 2019 Touchsada Jan On, Dean Zeller, and Dr. Chris Harris. This is original work, without use of outside sources.

# %% [markdown]
# # AnimalClass
# This class will represent one participant or contestant in the race.

# %%
class Animal:

   
    def __init__(self,name,species,speed,napStart,napDuration,currentPosition):
        self.name = name
        self.species = species
        self.speed = float(speed)
        self.napstart = napStart
        self.napduration = napDuration
        self.currentposition = float(currentPosition)
        self.time = 0
        self.napping = False
        return
       
    # get method
    def getName(self):
        return self.name
    def getSpeed(self):
        return self.speed
    def NapStart(self):
        return self.napstart
    def getNapDuration(self):
        return self.napduration
    def getCurrentPosition(self):
        return self.currentposition
    def getSpecies(self):
        return self.species
    # set method
    def setSpeed(self, num):
        self.speed = num
        return
    def setNapStart(self, num):
        self.napstart = num
        return
    def setNapDuration(self, num):
        self.napduration = num
        return
    def setCurrentPosition(self, num):
        self.napCurrentPos = num
        return
    def advancePosition(self):
        
        if self.time >= 0 and self.napstart < self.time and self.time < self.napstart + self.napduration:
            self.time += 1
            self.napping = False
        else:
            self.time += 1
            self.currentposition += self.speed
            self.napping = True
    def __str__(self):
        return str.format("%10s %8s" % ("{0:0.1f}".format(self.currentposition),"{0:0.1f}".format(self.speed)))

# %% [markdown]
# # AnimalTester
# This program have a sole purpose of thoroughly testing the Animal Object. This will intstantiate one participate for testing purposes.

# %%
class AnimalTester:
    con1 = Animal("Torry", "Tortoise", 1.6,0,0,0)
    con2 = Animal("Harry", "Hare", 12.0, 0,0,0)
    Horse = Animal("Hotty", "Horse", 20,0,0,0)
  # Hare
    print(con1.name)
    print(con1.species)
    print(con1.speed)
    print(con1.currentposition)
    print(con1) #String method
    print()
  # Tortoise
    print(con2.name)
    print(con2.species)
    print(con2.speed)
    print(con2.currentposition)
    print(con2)   # String Method 
    print()
  # Horse
    print(Horse.name)
    print(Horse.species)
    print(Horse.speed)
    print(Horse.currentposition)
    print(Horse) # String Method
# Out:
# Torry
# Tortoise
# 1.6
# 0.0
#        0.0      1.6
#
# Harry
# Hare
# 12.0
# 0.0
#        0.0     12.0
#
# Hotty
# Horse
# 20.0
# 0.0
#        0.0     20.0

# %% [markdown]
# # Class Race
# This class will represent two participant or contestants in a single race, also include default event name and race distance.

# %%
class Race:
    def __init__(self, contestant1, contestant2,eventname="Default Race Name", distance =100):
        self.eventname = eventname
        self.distance = distance
        self.con1 = contestant1
        self.con2 = contestant2
        self.time = 0
        self.napcount = 0
    def getEventName(self):
        return self.eventname
    def getDistance(self):
        return self.distance
    def runRace(self):
        comment = ""
        original = self.con2.speed
        print("%4s %10s %8s %10s %8s" %(self.time,self.con1.currentposition, self.con1.speed,self.con2.currentposition,self.con2.speed))
        while (self.con1.getCurrentPosition() < self.distance and self.con2.getCurrentPosition() < self.distance):
            comment = ""
            #Position
            self.con1.advancePosition()
            self.con2.advancePosition()
            #Defining animal base on race object and contestant object
            #Tortoise
            con1 = Animal(self.con1.name, self.con1.species, self.con1.speed,self.con1.napstart,self.con1.napduration,self.con1.currentposition)
            #Hare
            con2 = Animal(self.con2.name, self.con2.species, self.con2.speed,self.con2.napstart,self.con2.napduration,self.con2.currentposition)
        
            self.time += 1 
            
            if self.time == self.con2.napstart:
                comment = "\tNap Started"
            else:
                if self.time == self.con2.napstart+self.con2.napduration:
                    comment = "\tNap second " +str(self.napcount+1) + ", ending"
            
              #Naps
            if (self.con2.napstart < self.time < self.con2.napstart + self.con2.napduration):
                self.napcount += 1
                self.con2.speed = 0
                comment = "\tNapping second " + str(self.napcount)
      
            else:
                self.con2.speed = original
      
            #Hare Wins      
            if self.con1.getCurrentPosition() > self.con2.getCurrentPosition() and self.con1.getCurrentPosition() >= self.distance:
                comment = "\tRace over - " + con1.species + " Wins"
            #Tortoise Wins        
            if (self.con2.getCurrentPosition() > self.con1.getCurrentPosition() and self.con2.getCurrentPosition() >= self.distance):
                comment = "\tRace over - " + con2.species + " Wins"
            #Both are Tied
            if (self.con1.getCurrentPosition() == self.con2.getCurrentPosition() and self.con1.getCurrentPosition() >= self.distance):
                comment = "\tRace over - " + con1.species +" and " + con2.species + " are Tied!"
        
            
            print("%4d %4s %4s %4s" % (self.time, self.con1, self.con2, comment))
            
    def __str__(self):
        return str.format("%0s %12s %20s %15s" % (self.con1, self.con2, self.eventname, self.distance))

# %% [markdown]
# # RaceTester
# This program have a sole purpose of thoroughly testing the race Object. This will intstantiate one participate for testing purposes.

# %%
class RaceTester:
  
    race1 = Race("Cap","Lit","The Big Race", 1000)
    race2 = Race("Kyle","Lopez", "The Run 2019", 5000)
  #Final Race
    print(race1) # Have names of contestant, eventname and distance in race1
    print(race2) # Have names of contestant, eventname and distance in race2
    print(Race("Bobby", "Joe")) # Default eventname and distance
# Out:
# Cap          Lit         The Big Race            1000
# Kyle        Lopez         The Run 2019            5000
# Bobby          Joe    Default Race Name             100

# %% [markdown]
# # FinalRace!
# This program show the final race between the Tortoise and the Hare!

# %%
class FinalRace:
  #Animal
    con1 = Animal("Torry", "Tortoise", 1.6,0,0,0)
    con2 = Animal("Harry", "Hare", 12.0, 20,600,0)

  #Final Race
    race1 = Race(con1,con2,"Race1",1000)

    print("Tortoise v. Hare program\nBy Touchsada Jan On, CS120\n\nThis program recreates the famed story, The Tortoise and the Hare. Please enter the input value below.")
    print()
    print("%40s" % ("Race distance (feet): "), race1.distance)
    print("%40s" % ("Hare's speed (feet/sec): "), con2.speed)
    print("%40s" % ("Tortoise's speed (feet/sec): "), con1.speed)
    print("%40s" % ("Nap Start time: "), con2.napstart)
    print("%40s" % ("Nap duration: "), con2.napduration)
    print("\nThank you. Here is your race.")
    print()
    print("------------------------------------------------------------")

    print("%20s %20s" % (con1.species, con2.species))
    print("%0s %10s %8s %10s %8s %10s" % ("Time", "Position", "Speed", "Position", "Speed", "Comment"))
   
    race1.runRace()
# Out:
# Tortoise v. Hare program
# By Touchsada Jan On, CS120
#
# This program recreates the famed story, The Tortoise and the Hare. Please enter the input value below.
#
#                   Race distance (feet):  1000
#                Hare's speed (feet/sec):  12.0
#            Tortoise's speed (feet/sec):  1.6
#                         Nap Start time:  20
#                           Nap duration:  600
#
# Thank you. Here is your race.
#
# ------------------------------------------------------------
#             Tortoise                 Hare
# Time   Position    Speed   Position    Speed    Comment
#    0        0.0      1.6        0.0     12.0
#    1        1.6      1.6       12.0     12.0
#    2        3.2      1.6       24.0     12.0
#    3        4.8      1.6       36.0     12.0
#    4        6.4      1.6       48.0     12.0
#    5        8.0      1.6       60.0     12.0
#    6        9.6      1.6       72.0     12.0
#    7       11.2      1.6       84.0     12.0
# ...
